# %% [markdown]
# ### Carga de Librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ## Carga de datos
#
# #### Exploración inicial para conocer su dimensión y estructura. En esta fase analizaremos el número de filas, columnas y variables, así como el tipo de información que contiene el dataset.

# %%
df = pd.read_csv("../data/raw/resortworldwide.csv")
df.head()
# Out:
#                                                  URL  Rate  \
# 0  http://www.skiresort.info/ski-resort/kitzski-k...   4.9
# 1  http://www.skiresort.info/ski-resort/ischglsam...   4.8
# 2  http://www.skiresort.info/ski-resort/skiwelt-w...   4.8
# 3  http://www.skiresort.info/ski-resort/st-antons...   4.8
# 4  http://www.skiresort.info/ski-resort/serfaus-f...   4.8
#
#                          NameResort  Stars  Km Freeride Continent  Country  \
# 0     KitzSki – Kitzbühel/Kirchberg    5.0         45.0    Europe  Austria
# 1  Ischgl/Samnaun – Silvretta Arena    5.0         15.0    Europe  Austria
# 2   SkiWelt Wilder Kaiser-Brixental    5.0         26.0    Europe  Austria
# 3                       Ski Arlberg    5.0        200.0    Europe  Austria
# 4                Serfaus-Fiss-Ladis    5.0         28.0    Europe  Austria
#
#   State/Province  Altitude   Easy  Intermediate   Difficult Adult  \
# 0  Tyrol (Tirol)    2000.0  101.0           61.0       17.0    55
# ...

# %%
df.shape
# Out:
# (5478, 33)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5478 entries, 0 to 5477
# Data columns (total 33 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   URL                                                          5478 non-null   str
#  1   Rate                                                         3471 non-null   float64
#  2   NameResort                                                   5478 non-null   str
#  3   Stars                                                        413 non-null    float64
#  4   Km Freeride                                                  480 non-null    float64
#  5   Continent                                                    5469 non-null   str
#  6   Country                                                      5469 non-null   str
#  7   State/Province                                               5469 non-null   str
# ...

# %%
df.describe()
# Out:
#               Rate       Stars  Km Freeride     Altitude         Easy  \
# count  3471.000000  413.000000   480.000000  5469.000000  5478.000000
# mean      1.905733    2.970944     2.448958  1017.293107     4.016119
# std       0.940525    1.356082    10.217407   822.678565    11.666099
# min       0.000000    1.000000     0.000000     0.000000     0.000000
# 25%       1.200000    2.000000     0.000000   410.000000     0.300000
# 50%       1.500000    3.000000     0.000000   843.000000     1.000000
# 75%       2.500000    4.000000     3.000000  1500.000000     3.000000
# max       5.000000    5.000000   200.000000  5000.000000   312.000000
#
#        Intermediate     Difficult  Slope offering, variety of runs   \
# count    5478.000000  5478.000000                       3452.000000
# mean        4.548266     2.026908                          1.954287
# std        13.266404     6.697797                          1.054178
# ...

# %% [markdown]
# ## Valores Nulos

# %%
df.isnull().sum()
# Out:
# URL                                                               0
# Rate                                                           2007
# NameResort                                                        0
# Stars                                                          5065
# Km Freeride                                                    4998
# Continent                                                         9
# Country                                                           9
# State/Province                                                    9
# Altitude                                                          9
# Easy                                                              0
# Intermediate                                                      0
# Difficult                                                         0
# Adult                                                             9
# Currency                                                          9
# ...

# %%
(df.isnull().sum() / len(df) * 100).sort_values(ascending=False)
# Out:
# Stars                                                          92.460752
# Accommodation offering directly at the slopes and lifts        92.168675
# Après-ski                                                      92.168675
# Mountain restaurants, ski huts, gastronomy                     92.168675
# Environmentally friendly ski operation                         92.168675
# Cross-country skiing and trails                                92.168675
# Snow parks                                                     92.168675
# Beginners                                                      92.168675
# Families and children                                          92.168675
# Cleanliness and hygiene                                        92.168675
# Orientation (trail map, information boards, sign-postings)     92.168675
# Access, on-site parking                                        92.168675
# Snow reliability                                               92.168675
# ...

# %%
df.describe().T
# Out:
#                                    count         mean         std         min  \
# Rate                              3471.0     1.905733    0.940525    0.000000
# Stars                              413.0     2.970944    1.356082    1.000000
# Km Freeride                        480.0     2.448958   10.217407    0.000000
# Altitude                          5469.0  1017.293107  822.678565    0.000000
# Easy                              5478.0     4.016119   11.666099    0.000000
# Intermediate                      5478.0     4.548266   13.266404    0.000000
# Difficult                         5478.0     2.026908    6.697797    0.000000
# Slope offering, variety of runs   3452.0     1.954287    1.054178    0.000000
# Snow reliability                   429.0     3.850816    1.113272    1.000000
# latitude                          4880.0    45.651246   13.995871  -40.900557
# longitude                         4880.0    27.153449   57.856092 -106.346771
# ...

# %%
df.describe(include="object").T
# Out:
# C:\Users\dieve\AppData\Local\Temp\ipykernel_3920\1274302342.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include="object").T
#                                                    count unique  \
# URL                                                 5478   5478
# NameResort                                          5478   5478
# Continent                                           5469      6
# Country                                             5469     90
# State/Province                                      5469    418
# ...

# %% [markdown]
# #### Tras la exploración inicial se observa que el dataset cuenta con un volumen de datos suficiente para realizar el análisis. No existen registros duplicados, aunque varias variables presentan un porcentaje elevado de valores nulos que deberán estudiarse durante el preprocesamiento para decidir si conviene eliminarlas o arreglarlas.
